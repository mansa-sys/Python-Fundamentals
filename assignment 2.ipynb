# %%
#Assignment 2
# Python program to check if the given number is prime or not?
n= int(input("ENTER A NUMBER:"))
if n<=1:
    print(n, " NOT A PRIME NUMBER")
else:
       for i in range (2,n):
          if (n%i) ==0:
              print (n," IS NOT A PRIME NUMBER")
              break
       else:
        print (n," IS A PRIME NUMBER")
# Out:
# ENTER A NUMBER: 6
# 6  IS NOT A PRIME NUMBER

# %%
# To check for Palindrome, Armstrong & Fibonacci Series.
n= int(input("ENTER A NUMBER:"))
x= n
reverse= 0
while x>0:
    digit= x%10
    reverse= reverse*10+digit
    x//= 10
if n==reverse:
    print(n," IS A PALINDROME NUMBER")
else:
    print(n," IS NOT A PALINDROME NUMBER")
# Out:
# ENTER A NUMBER: 676
# 676  IS A PALINDROME NUMBER

# %%
n= int(input("ENTER A NUMBER:"))
x= n
order= len(str(n))
sum= 0
while x>0:
    last_digit= x%10
    sum+= last_digit**order
    x//=10
if n==sum:
    print(n," IS AN ARMSTRONG NUMBER")
else:
    print(n," IS NOT AN ARMSTRONG NUMBER")
# Out:
# ENTER A NUMBER: 56
# 56  IS NOT AN ARMSTRONG NUMBER

# %%
n= int(input("ENTER LENGTH OF SERIES:"))
a,b= 0,1
print("FIBONACCI SERIES:")
for i in range(n):
    print(a, end=" ")
    a,b = b,a +b
# Out:
# ENTER LENGTH OF SERIES: 5
# FIBONACCI SERIES:
# 0 1 1 2 3
